# %% [markdown]
# # Simple Linear Regression
# One input column and one output column.

# %% [markdown]
# ### TODO:
# - Step1: Import libraries and Load data
# - Step2: Visualize + Split (Train and Test Data)
# - Step3: Train the model
# - Step4: Predict and Evaluate the Model
# - Step4: Find the Value of Y-Intercept(lr_obj.intercept_) and Slope(lr_obj.coef_).

# %% [markdown]
# ## Step1

# %%
import pandas as pd, seaborn as sns, matplotlib. pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("SLR.csv")
data
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %% [markdown]
# ## Step2

# %%
fig , (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(14,4))

ax1.set_title("CGPA Distribution")
data['cgpa'].plot(kind='kde',ax=ax1)

ax2.set_title("Package Distribution")
data['package'].plot(kind='kde',ax=ax2)

ax3.set_title("CGPA and Package Relation")
sns.scatterplot(data=data,x='cgpa',y='package',ax=ax3)
# Out:
# <Axes: title={'center': 'CGPA and Package Relation'}, xlabel='cgpa', ylabel='package'>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data['cgpa'],data['package'],test_size=0.2, random_state=2)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Step3: Train the Model

# %%
# Step1: Import the libraries
# Already imported

# Step2: Create an object
lr = LinearRegression()

# Step3: fir the data
lr.fit(X_train.values, Y_train.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 8
#       5 lr = LinearRegression()
#       7 # Step3: fir the data
# ----> 8 lr.fit(X_train.values, Y_train.values)
#
# File a:\py-code\1-ML\Algorithms\K-Discovery-LR\venv\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File a:\py-code\1-ML\Algorithms\K-Discovery-LR\venv\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
# ...

# %% [markdown]
# ## Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#
# ![image.png](attachment:image.png)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# ((160,), (40,), (160,), (40,))
# Out:
# ((160,), (40,), (160,), (40,))

# %%
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)
Y_train = Y_train.values.reshape(-1,1)
Y_test = Y_test.values.reshape(-1,1)

X_train.shape, X_test.shape, Y_train.shape, Y_test.shape, type(X_train), type(X_test), type(Y_train), type(Y_test)
# Out:
# ((160, 1),
#  (40, 1),
#  (160, 1),
#  (40, 1),
#  numpy.ndarray,
#  numpy.ndarray,
#  numpy.ndarray,
#  numpy.ndarray)

# %%
# Step1: Import the libraries
# Already imported

# Step2: Create an object
lr = LinearRegression()

# Step3: fir the data
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Step4: Predict and Evaluate

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[3.89111601],
#        [3.09324469],
#        [2.38464568],
#        [2.57434935],
#        [1.6537286 ],
#        [1.77647803],
#        [2.07219258],
#        [2.93143862],
#        [3.76278706],
#        [2.93701814],
#        [4.09197872],
#        [3.51170867],
#        [2.97049525],
#        [2.40138424],
#        [3.18809652],
#        [3.46707251],
#        [1.94386362],
#        [3.24389172],
#        [2.97607477],
#        [3.41685683],
#        [2.55761079],
#        [3.16577844],
#        [2.85890486],
#        [3.12114229],
#        [3.68467378],
#        [2.8700639 ],
#        [3.49497011],
#        [3.34432308],
#        [3.91901361],
#        [1.96060218],
#        [3.65119666],
#        [3.2104146 ],
#        [3.74046898],
#        [2.7863711 ],
#        [2.78079158],
#        [3.27178932],
#        [3.52844723],
#        [2.61340599],
#        [2.65804215],
#        [2.71383735]])

# %% [markdown]
# ## How to get the accuracy score of this kind of data?

# %%
# valuate the model using metrics
mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 0.12129235313495527
# R-squared: 0.780730147510384

# %%
# x = 8.58 : first row value

lr.predict(X_test.iloc[0].reshape(1,1))
# Out:
# array([[3.89111601]])

# %%
plt.scatter(data['cgpa'],data['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %% [markdown]
# ## Step5: Intercept and Slope.

# %%
m = lr.coef_

# %%
c = lr.intercept_

# %%
# y = mx + c 
y  = m * 8.58 + c
y # pedicted value or  y hat.
# Out:
# array([[3.89111601]])
